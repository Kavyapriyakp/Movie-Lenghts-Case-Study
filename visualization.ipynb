# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %%
import scipy.intergrate as integrate
def f(a,b):
    return a+b
integrate.dblquad(f, 0,1, lambda x:0, lambda x:5)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-93226c2c60a7> in <module>
# ----> 1 import scipy.intergrate as integrate
#       2 def f(a,b):
#       3     return a+b
#       4 integrate.dblquad(f, 0,1, lambda x:0, lambda x:5)
#
# ModuleNotFoundError: No module named 'scipy.intergrate'
